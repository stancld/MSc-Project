# %% [markdown]
# ## 1. Setup and Import libraries

# %%
# django path
mysite_path = "C:\\Data\\UCL\\@MSc Project\\DB\\mysite\\"

# %%
# standard packages
import os
import sys
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import django
from set_django_db import set_django_db
from asgiref.sync import sync_to_async

from IPython.core.display import HTML

# %matplotlib inline

# %%
# set django models
set_django_db(mysite_path)
from tables_daniel.models import Company, Review

# specifically for Jupyter notebooks
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
# center plots
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical_align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical_align: middle;
# }
# </style>

# %% [markdown]
# ## 2. Load, merge and filter the datasets
#
# <hr>
#
# **Content**
#
#     2.1 Load companies
#     2.2 Load reviews
#     2.3 Some useful merges/adds
#     2.4 Filter the data from the monitored period between 2018-07-01 and 2020-06-30
#     2.5 Filter only the reviews for the companies with at least 10 reviews

# %% [markdown]
# ### 2.1 Companies

# %%
companies = pd.DataFrame(
    list(
        Company
        .objects
        .values('id', 'Company', 'Sector', 'ListedOn')
        .all()
    )
)

companies_id = list(companies.id)

# %% [markdown]
# ### 2.2 Reviews

# %%
reviews = list(
    Review
    .objects
    .values(
        'id', 'Company_id', 'ReviewTitle', 'Rating',
        'JobTitle', 'EmployeeRelationship',
        'Contract', 'Pros', 'Cons'
    )
    .all()
    .filter(Company_id = company_id) for company_id in companies_id
)

reviews_df = pd.DataFrame(
    sum([list(reviews_i) for reviews_i in reviews],[])
).drop_duplicates()

# %%
row = dict(reviews_df.iloc[0,:])
row['id']

Review.objects.values('id', 'JobTitle', 'EmployeeRelationship').filter(id=row['id']).update(JobTitle='Former Employee')
# Out:
# 1

# %%
for i in range(reviews_df.shape[0]):
    row = dict(reviews_df.iloc[i,:])
    
    review = (
        Review
        .objects
        .values('id', 'JobTitle' ,'EmployeeRelationship')
        .get(id=row['id'])
    )
    
    if review 'JobTitle' in ['Former Employee', 'Current Employee']:
        new_jobTitle = review['EmployeeRelationship']
        new_relationship = review['JobTitle']
        
        (Review
         .objects
         .filter(id=row['id'])
         .update(
             JobTitle = new_jobTitle,
             EmployeeRelationship = new_relationship
         )
        )
    else:
        pass
# Out:
# {'id': 24966, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Anonymous Employee'}
# {'id': 24967, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Software Engineer'}
# {'id': 24968, 'JobTitle': 'Current Employee', 'EmployeeRelationship': 'Manager/In'}
# {'id': 24969, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Sales Assistant'}
# {'id': 24970, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Questions Solving'}
# {'id': 24971, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Retail Sales Associate'}
# {'id': 24972, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Team Lead'}
# {'id': 24973, 'JobTitle': 'Current Employee', 'EmployeeRelationship': 'Supervisor'}
# {'id': 24974, 'JobTitle': 'Current Employee', 'EmployeeRelationship': 'Business Solutions Manager'}
# {'id': 24975, 'JobTitle': 'Former Employee', 'EmployeeRelationship': 'Senior Manager'}

# %%
reviews = list(
    Review
    .objects
    .values('Company_id', 'ReviewTitle', 'Rating', 'Pros', 'Cons', 'Year', 'Month', 'Day',
            'JobTitle', 'Contract', 'EmployeeRelationship')
    .all()
)

reviews_df = pd.DataFrame(
    sum([list(reviews_i) for reviews_i in reviews],[])
).drop_duplicates()

# %% [markdown]
# ### 2.3 Some useful merges/adds

# %%
# add sector and company name
reviews_df = reviews_df.merge(
    companies[['id', 'Company', 'Sector']].rename(columns={'id': 'Company_id',
                                                           'Company': 'Company',
                                                           'Sector': 'Sector'                                                 
                                                }),
    on='Company_id'
)

# add date column used for filtering
reviews_df['Date'] = reviews_df.apply(lambda x: '-'.join(
    [str(x['Year']), str(x['Month']), str(x['Day'])]
    ), axis=1
)

reviews_df
# Out:
#         Company_id                                       ReviewTitle  Rating  \
# 0                1                                         Part Time     4.0
# 1                1                               Terrible experience     1.0
# 2                1                                               Top     5.0
# 3                1                                   Sales Assistant     4.0
# 4                1  My experience is too maintain the task and group     2.0
# ...            ...                                               ...     ...
# 402517         649                                            Review     4.0
# 402518         649                                 Engaging Projects     4.0
# 402519         649                    Healthcare and 401k are a joke     1.0
# 402520         649                            Where hacks go to die.     1.0
# 402521         649                No one here gets out alive. Avoid.     1.0
#
#                                                      Pros  \
# 0       Friendly colleagues, willing to give you disco...
# 1       Some nice welcoming colleagues and benefits (M...
# 2              Work-Life Balance, nice offices, top sport
# 3         Staff helpfulPay was goof Staff are respectuful
# 4          My biggest dream is to work with Adidas family
# ...                                                   ...
# 402517  Work-life balance, great if you have a young f...
# 402518  Flexibility, Responsibility, Authority to get ...
# 402519                none  - 401k match is extremely low
# 402520               Lack of talent is considered a plus.
# 402521                   Ok salary. Work/life balance ok.
#
#                                                      Cons  Year  Month  Day  \
# 0       There are some politics going on (like any oth...  2020      7    1
# 1       Really poor culture and collaboration spirit, ...  2020      7    1
# 2                    Global company, long decision making  2020      6   30
# 3                               Might get a little hectic  2020      6   29
# 4       Difficult to maintain but once know easy to ha...  2020      6   28
# ...                                                   ...   ...    ...  ...
# 402517              Lack of structured career progression  2018      8   27
# 402518  Working across agencies is fun but rarely stru...  2018      8   18
# 402519  401k has a tiny match, why bother?Healthcare i...  2018      8   16
# 402520  Impersonal, low paying, account folk rule the ...  2018      7   17
# 402521  Difficult to know where to begin. Basically, d...  2018      6   26
#
#                 JobTitle   Contract    EmployeeRelationship  Company  \
# 0        Former Employee  part-time      Anonymous Employee   Adidas
# 1        Former Employee  full-time       Software Engineer   Adidas
# 2       Current Employee  full-time              Manager/In   Adidas
# 3        Former Employee  part-time         Sales Assistant   Adidas
# 4        Former Employee  part-time       Questions Solving   Adidas
# ...                  ...        ...                     ...      ...
# 402517   Former Employee  full-time      Anonymous Employee  WPP plc
# 402518   Former Employee  full-time  Senior Project Manager  WPP plc
# 402519  Current Employee  full-time      Anonymous Employee  WPP plc
# 402520   Former Employee  full-time      Anonymous Employee  WPP plc
# 402521   Former Employee  full-time      Anonymous Employee  WPP plc
#
#                         Sector       Date
# 0            Consumer Cyclical   2020-7-1
# 1            Consumer Cyclical   2020-7-1
# 2            Consumer Cyclical  2020-6-30
# 3            Consumer Cyclical  2020-6-29
# 4            Consumer Cyclical  2020-6-28
# ...                        ...        ...
# 402517  Communication Services  2018-8-27
# 402518  Communication Services  2018-8-18
# 402519  Communication Services  2018-8-16
# 402520  Communication Services  2018-7-17
# 402521  Communication Services  2018-6-26
#
# [402522 rows x 14 columns]

# %%
def string_to_date(date_str):
    try:
        return datetime.strptime(date_str, '%Y-%m-%d')
    except:
        return datetime.strptime('1800-1-1', '%Y-%m-%d')
    
def string_to_YM(date_str):
    try:
        return datetime.strptime(date_str, '%Y-%m')
    except:
        return datetime.strptime('1800-1-1', '%Y-%m-%d')

reviews_df['Date'] = reviews_df['Date'].apply(lambda x: string_to_date(x))

reviews_df['Year-Month'] = reviews_df.apply(lambda x: string_to_YM('-'.join([str(x['Year']), str(x['Month'])])), axis=1)

# %% [markdown]
# ### 2.4 Filter the data from the monitored period between

# %%
# further analysis focusing only on the companies with at least 10 reviews in the monitored period
min_date = datetime.strptime('2018-7-1', '%Y-%m-%d')
max_date = datetime.strptime('2020-6-30', '%Y-%m-%d')

reviews_df = pd.DataFrame(
    reviews_df[(reviews_df.Date >= min_date) & (reviews_df.Date <= max_date)]
)

reviews_df
# Out:
#         Company_id                                       ReviewTitle  Rating  \
# 2                1                                               Top     5.0
# 3                1                                   Sales Assistant     4.0
# 4                1  My experience is too maintain the task and group     2.0
# 5                1                                         great job     4.0
# 6                1                             Sales Floor Team lead     3.0
# ...            ...                                               ...     ...
# 402516         649                   Don't even consider going there     1.0
# 402517         649                                            Review     4.0
# 402518         649                                 Engaging Projects     4.0
# 402519         649                    Healthcare and 401k are a joke     1.0
# 402520         649                            Where hacks go to die.     1.0
#
#                                                      Pros  \
# 2              Work-Life Balance, nice offices, top sport
# 3         Staff helpfulPay was goof Staff are respectuful
# 4          My biggest dream is to work with Adidas family
# 5            cool team fun work environment great company
# 6       employee discount 40-60% most items excluding ...
# ...                                                   ...
# 402516          - There are some talented and nice people
# 402517  Work-life balance, great if you have a young f...
# 402518  Flexibility, Responsibility, Authority to get ...
# 402519                none  - 401k match is extremely low
# 402520               Lack of talent is considered a plus.
#
#                                                      Cons  Year  Month  Day  \
# 2                    Global company, long decision making  2020      6   30
# 3                               Might get a little hectic  2020      6   29
# 4       Difficult to maintain but once know easy to ha...  2020      6   28
# 5                   dealing with some difficult customers  2020      6   28
# 6       low paid job, almost much minimum wage to star...  2020      6   27
# ...                                                   ...   ...    ...  ...
# 402516  - Lives up to all the bad stereotypes of agenc...  2018      8   28
# 402517              Lack of structured career progression  2018      8   27
# 402518  Working across agencies is fun but rarely stru...  2018      8   18
# 402519  401k has a tiny match, why bother?Healthcare i...  2018      8   16
# 402520  Impersonal, low paying, account folk rule the ...  2018      7   17
#
#                 JobTitle   Contract    EmployeeRelationship  Company  \
# 2       Current Employee  full-time              Manager/In   Adidas
# 3        Former Employee  part-time         Sales Assistant   Adidas
# 4        Former Employee  part-time       Questions Solving   Adidas
# 5        Former Employee  part-time  Retail Sales Associate   Adidas
# 6        Former Employee  full-time               Team Lead   Adidas
# ...                  ...        ...                     ...      ...
# 402516   Former Employee  full-time        Account Director  WPP plc
# 402517   Former Employee  full-time      Anonymous Employee  WPP plc
# 402518   Former Employee  full-time  Senior Project Manager  WPP plc
# 402519  Current Employee  full-time      Anonymous Employee  WPP plc
# 402520   Former Employee  full-time      Anonymous Employee  WPP plc
#
#                         Sector       Date Year-Month
# 2            Consumer Cyclical 2020-06-30 2020-06-01
# 3            Consumer Cyclical 2020-06-29 2020-06-01
# 4            Consumer Cyclical 2020-06-28 2020-06-01
# 5            Consumer Cyclical 2020-06-28 2020-06-01
# 6            Consumer Cyclical 2020-06-27 2020-06-01
# ...                        ...        ...        ...
# 402516  Communication Services 2018-08-28 2018-08-01
# 402517  Communication Services 2018-08-27 2018-08-01
# 402518  Communication Services 2018-08-18 2018-08-01
# 402519  Communication Services 2018-08-16 2018-08-01
# 402520  Communication Services 2018-07-17 2018-07-01
#
# [392016 rows x 15 columns]

# %% [markdown]
# ### 2.5 Filter only the reviews for companies with at least 10 reviews

# %%
# count reviews
reviews_count = (
    reviews_df
    .groupby('Company')
    .Rating
    .count()
)

# filter companies
companies_filtered = list(reviews_count[reviews_count>10].index)

# %%
reviews_df = reviews_df[reviews_df.Company.isin(companies_filtered)]

print(
    f"There are {reviews_df.shape[0]:.0f} reviews in total."
)
# Out:
# There are 391869 reviews in total.

# %% [markdown]
# ## 3. Summary statistics
#
# <hr>
#
# **Content**
#
#     3.1 Distribution of reviews over former/current and part/full-time employees

# %% [markdown]
# ### 3.1 Distribution of reviews over former/current and part/full-time employees

# %%
reviews_df.head()
# Out:
#    Company_id                                       ReviewTitle  Rating  \
# 2           1                                               Top     5.0
# 3           1                                   Sales Assistant     4.0
# 4           1  My experience is too maintain the task and group     2.0
# 5           1                                         great job     4.0
# 6           1                             Sales Floor Team lead     3.0
#
#                                                 Pros  \
# 2         Work-Life Balance, nice offices, top sport
# 3    Staff helpfulPay was goof Staff are respectuful
# 4     My biggest dream is to work with Adidas family
# 5       cool team fun work environment great company
# 6  employee discount 40-60% most items excluding ...
#
#                                                 Cons  Year  Month  Day  \
# 2               Global company, long decision making  2020      6   30
# 3                          Might get a little hectic  2020      6   29
# 4  Difficult to maintain but once know easy to ha...  2020      6   28
# 5              dealing with some difficult customers  2020      6   28
# 6  low paid job, almost much minimum wage to star...  2020      6   27
#
#            JobTitle   Contract    EmployeeRelationship Company  \
# 2  Current Employee  full-time              Manager/In  Adidas
# 3   Former Employee  part-time         Sales Assistant  Adidas
# 4   Former Employee  part-time       Questions Solving  Adidas
# 5   Former Employee  part-time  Retail Sales Associate  Adidas
# 6   Former Employee  full-time               Team Lead  Adidas
#
#               Sector       Date Year-Month
# 2  Consumer Cyclical 2020-06-30 2020-06-01
# 3  Consumer Cyclical 2020-06-29 2020-06-01
# 4  Consumer Cyclical 2020-06-28 2020-06-01
# 5  Consumer Cyclical 2020-06-28 2020-06-01
# 6  Consumer Cyclical 2020-06-27 2020-06-01

# %%
print(
    reviews_df
    .groupby('JobTitle')
    .Company
    .count()
)
# Out:
# JobTitle
#                                                         8
# "Delegado comercial, área internacional"                1
# "Marketing"                                             1
# "Sales, Marketing and Business Intelligence Analyst"    1
# (Classified)                                            1
#                                                        ..
# Yield Engineer                                          4
# Yield Enhancement Engineer                              1
# YouTube                                                 1
# genious                                                 2
# microarchitect                                          1
# Name: Company, Length: 5640, dtype: int64
