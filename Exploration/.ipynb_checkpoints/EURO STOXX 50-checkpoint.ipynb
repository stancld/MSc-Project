# %% [markdown]
# ## 1. Setup and Import libraries

# %%
# django path
mysite_path = "C:\\Data\\UCL\\@MSc Project\\DB\\mysite\\"

# %%
# standard packages
import os
import sys
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import django
from set_django_db import set_django_db
from asgiref.sync import sync_to_async

from IPython.core.display import HTML

# %matplotlib inline

# %%
# set django models
set_django_db(mysite_path)
from tables_daniel.models import Company, Review

# specifically for Jupyter notebooks
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
# set pandas display
pd.set_option('display.max_rows', 100)

# %%
# center plots
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical_align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical_align: middle;
# }
# </style>

# %% [markdown]
# ## 2. Filter companies (+reviews) listed on EURO STOXX 50

# %% [markdown]
# ### 2.1 Load the data

# %% [markdown]
# #### 2.1.1 Companies

# %%
companies = pd.DataFrame(
    list(
        Company
        .objects
        .values('id', 'Company', 'Country', 'Sector', 'Industry', 'NoEmployees', 'Revenue')
        .all()
        .filter(ListedOn='EURO STOXX 50')
    )
)

# %%
companies['TotalReviews'] = 0

def sumReviews(row):
    try:
        return len(
            list(
                Review
                .objects
                .all()
                .filter(Company=companies.loc[row, 'id'])
            )
        )
    except:
        return 0


for row in range(companies.shape[0]):
    companies.loc[row, 'TotalReviews'] = sumReviews(row)

# %%
companies
# Out:
#     id                           Company      Country                  Sector  \
# 0    1                            Adidas      Germany       Consumer Cyclical
# 1    2                    Ahold Delhaize  Netherlands      Consumer Defensive
# 2    3                       Air Liquide       France         Basic Materials
# 3    4                            Airbus  Netherlands             Industrials
# 4    5                           Allianz      Germany      Financial Services
# 5    6              Anheuser-Busch InBev      Belgium      Consumer Defensive
# 6    7                      ASML Holding  Netherlands              Technology
# 7    8                               AXA       France      Financial Services
# 8    9   Banco Bilbao Vizcaya Argentaria        Spain      Financial Services
# 9   10                   Banco Santander        Spain      Financial Services
# 10  11                              BASF      Germany         Basic Materials
# 11  12                             Bayer      Germany              Healthcare
# 12  13                               BMW      Germany       Consumer Cyclical
# 13  14                       BNP Paribas       France      Financial Services
# 14  15                               CRH      Ireland         Basic Materials
# 15  16         Compagnie de Saint-Gobain       France             Industrials
# 16  17                        Daimler AG      Germany       Consumer Cyclical
# 17  18                     Deutsche Post      Germany             Industrials
# 18  19                  Deutsche Telekom      Germany  Communication Services
# 19  20                              Enel        Italy               Utilities
# 20  21                             Engie       France               Utilities
# 21  22                               Eni        Italy                  Energy
# 22  23                              E.ON      Germany               Utilities
# 23  24                  EssilorLuxottica       France              Healthcare
# 24  25                      Fresenius SE      Germany              Healthcare
# 25  26                     Groupe Danone       France      Consumer Defensive
# 26  27                         Iberdrola        Spain               Utilities
# 27  28                           Inditex        Spain       Consumer Cyclical
# 28  29                         ING Group  Netherlands      Financial Services
# 29  30                   Intesa Sanpaolo        Italy      Financial Services
# 30  31                         Linde plc      Ireland         Basic Materials
# 31  32                           L'Oréal       France      Consumer Defensive
# 32  33  LVMH Moët Hennessy Louis Vuitton       France       Consumer Cyclical
# 33  34                         Munich Re      Germany      Financial Services
# 34  35                             Nokia      Finland              Technology
# 35  36                       Orange S.A.       France  Communication Services
# 36  37                           Philips  Netherlands              Healthcare
# 37  38                            Safran       France             Industrials
# 38  39                            Sanofi       France              Healthcare
# 39  40                            SAP SE      Germany              Technology
# 40  41                Schneider Electric       France             Industrials
# 41  42                           Siemens      Germany             Industrials
# 42  43               Société Générale SA       France      Financial Services
# 43  44                        Telefónica        Spain  Communication Services
# 44  45                        TOTAL S.A.       France                  Energy
# 45  46                   Unibail-Rodamco       France             Real Estate
# 46  47                          Unilever  Netherlands      Consumer Defensive
# 47  48                          Vinci SA       France             Industrials
# 48  49                           Vivendi       France  Communication Services
# 49  50                  Volkswagen Group      Germany       Consumer Cyclical
#
#                                Industry  NoEmployees      Revenue  \
# 0                Footwear & Accessories        53218   22498000.0
# 1                        Grocery Stores       380000   68589000.0
# 2                             Chemicals        67200   21920100.0
# 3                   Aerospace & Defense       136518   68560000.0
# 4                 Insurance—Diversified       147268  109102000.0
# 5                     Beverages—Brewers       170000   50743000.0
# 6   Semiconductor Equipment & Materials        23860   12031500.0
# 7                 Insurance—Diversified       115070  124941000.0
# 8                     Banks—Diversified       126041   22987000.0
# 9                     Banks—Diversified       194948   42777000.0
# 10                            Chemicals       118276   60473000.0
# 11           Drug Manufacturers—General       102201   44138000.0
# 12                   Auto Manufacturers       133778  105000000.0
# 13                       Banks—Regional       199000   54749000.0
# 14                   Building Materials        80300          0.0
# 15        Building Products & Equipment       170643   42573000.0
# 16                   Auto Manufacturers       298611  170270000.0
# 17       Integrated Freight & Logistics       540841   63475000.0
# 18                     Telecom Services       206443   80648000.0
# 19                Utilities—Diversified        67921   60722000.0
# 20                Utilities—Diversified       171000   60058000.0
# 21                 Oil & Gas Integrated        32053   65166000.0
# 22                Utilities—Diversified        73229   49739000.0
# 23       Medical Instruments & Supplies       152954   17391000.0
# 24              Medical Care Facilities       299594   36049000.0
# 25                       Packaged Foods       102449   25287000.0
# 26                Utilities—Diversified        35107   35724908.0
# 27                       Apparel Retail        75942   25661000.0
# 28                    Banks—Diversified        55452   16957000.0
# 29                       Banks—Regional        88130   31126000.0
# 30                  Specialty Chemicals        79008   28023000.0
# 31        Household & Personal Products        87974   29873600.0
# 32                         Luxury Goods       147715   53650000.0
# 33                Insurance—Reinsurance        39641   56093000.0
# 34              Communication Equipment        98322   23196000.0
# 35                     Telecom Services       135619   42237000.0
# 36               Diagnostics & Research        80718   19489000.0
# 37                  Aerospace & Defense        91610   25098000.0
# 38           Drug Manufacturers—General       100409   38234000.0
# 39                 Software—Application       101150   27553000.0
# 40       Specialty Industrial Machinery       135000   27158000.0
# 41       Specialty Industrial Machinery       385000   87315000.0
# 42                       Banks—Regional       138000   31906000.0
# 43                     Telecom Services       114042   47809000.0
# 44                 Oil & Gas Integrated       107776  169702000.0
# 45                          REIT—Retail         3495    3380900.0
# 46        Household & Personal Products       149867   51980000.0
# 47           Engineering & Construction       219267   48950000.0
# 48                         Broadcasting        43900   15898000.0
# 49                   Auto Manufacturers       670011  247675000.0
#
#     TotalReviews
# 0            720
# 1             50
# 2             40
# 3            350
# 4            500
# 5            570
# 6             70
# 7            570
# 8            140
# 9            230
# 10           130
# 11           640
# 12           260
# 13           970
# 14            70
# 15           290
# 16           160
# 17            70
# 18            70
# 19            50
# 20           240
# 21            90
# 22           190
# 23             0
# 24            30
# 25           240
# 26            10
# 27           160
# 28           310
# 29            30
# 30           200
# 31           650
# 32           120
# 33            80
# 34          2960
# 35           520
# 36           290
# 37           190
# 38           670
# 39          4270
# 40          1410
# 41          1920
# 42            70
# 43           170
# 44           260
# 45            66
# 46          1180
# 47            40
# 48             9
# 49           150

# %% [markdown]
# #### 2.1.2 Reviews

# %%
companies_id = list(companies.id)

# %%
reviews = list(
    Review
    .objects
    .values('Company_id', 'ReviewTitle', 'Rating', 'Pros', 'Cons', 'Year', 'Month', 'Day',
            'JobTitle', 'EmployeeRelationship')
    .all()
    .filter(Company_id = company_id) for company_id in companies_id
)

# %%
reviews_df = pd.DataFrame(
    sum([list(reviews_i) for reviews_i in reviews],[])
)

# %%
reviews_df.head()
# Out:
#    Company_id                                       ReviewTitle  Rating  \
# 0           1                                         Part Time     4.0
# 1           1                               Terrible experience     1.0
# 2           1                                               Top     5.0
# 3           1                                   Sales Assistant     4.0
# 4           1  My experience is too maintain the task and group     2.0
#
#                                                 Pros  \
# 0  Friendly colleagues, willing to give you disco...
# 1  Some nice welcoming colleagues and benefits (M...
# 2         Work-Life Balance, nice offices, top sport
# 3    Staff helpfulPay was goof Staff are respectuful
# 4     My biggest dream is to work with Adidas family
#
#                                                 Cons  Year  Month  Day  \
# 0  There are some politics going on (like any oth...  2020      7    1
# 1  Really poor culture and collaboration spirit, ...  2020      7    1
# 2               Global company, long decision making  2020      6   30
# 3                          Might get a little hectic  2020      6   29
# 4  Difficult to maintain but once know easy to ha...  2020      6   28
#
#            JobTitle EmployeeRelationship
# 0   Former Employee   Anonymous Employee
# 1   Former Employee    Software Engineer
# 2  Current Employee           Manager/In
# 3   Former Employee      Sales Assistant
# 4   Former Employee    Questions Solving

# %% [markdown]
# ### 2.2 DF transformation

# %% [markdown]
# Add some useful columns

# %%
reviews_df = reviews_df.merge(
    companies[['id', 'Company', 'Sector']].rename(columns={'id': 'Company_id',
                                                           'Company': 'Company',
                                                           'Sector': 'Sector'                                                 
                                                }),
    on='Company_id'
)

# %%
reviews_df['Date'] = reviews_df.apply(lambda x: '-'.join(
    [str(x['Year']), str(x['Month']), str(x['Day'])]
    ), axis=1
)

reviews_df
# Out:
#        Company_id                                       ReviewTitle  Rating  \
# 0               1                                         Part Time     4.0
# 1               1                               Terrible experience     1.0
# 2               1                                               Top     5.0
# 3               1                                   Sales Assistant     4.0
# 4               1  My experience is too maintain the task and group     2.0
# ...           ...                                               ...     ...
# 22470          50                           New Projects Specialist     5.0
# 22471          50                             good global practices     3.0
# 22472          50                                    company reviwe     3.0
# 22473          50                         Good Money, Tough Culture     3.0
# 22474          50                                   Service advisor     5.0
#
#                                                     Pros  \
# 0      Friendly colleagues, willing to give you disco...
# 1      Some nice welcoming colleagues and benefits (M...
# 2             Work-Life Balance, nice offices, top sport
# 3        Staff helpfulPay was goof Staff are respectuful
# 4         My biggest dream is to work with Adidas family
# ...                                                  ...
# 22470  Relationships, expertise, and logistics knowledge
# 22471    Unique global atndards and less local practices
# 22472                  good work culture and environment
# 22473  Volkswagen pays very well and the bonus is pre...
# 22474           Good communication with higher officials
#
#                                                     Cons  Year  Month  Day  \
# 0      There are some politics going on (like any oth...  2020      7    1
# 1      Really poor culture and collaboration spirit, ...  2020      7    1
# 2                   Global company, long decision making  2020      6   30
# 3                              Might get a little hectic  2020      6   29
# 4      Difficult to maintain but once know easy to ha...  2020      6   28
# ...                                                  ...   ...    ...  ...
# 22470  A lor of time to grow in the company, few prom...  2018      7   12
# 22471      salary low promotion strategy not encpuraging  2018      7    8
# 22472         unstable top management ,less transparency  2018      6   27
# 22473  The culture is very hierarchal and the managem...  2018      6   25
# 22474                         Not a clear follow of work  2018      6   12
#
#                JobTitle      EmployeeRelationship           Company  \
# 0       Former Employee        Anonymous Employee            Adidas
# 1       Former Employee         Software Engineer            Adidas
# 2      Current Employee                Manager/In            Adidas
# 3       Former Employee           Sales Assistant            Adidas
# 4       Former Employee         Questions Solving            Adidas
# ...                 ...                       ...               ...
# 22470  Current Employee        Anonymous Employee  Volkswagen Group
# 22471   Former Employee                   Manager  Volkswagen Group
# 22472  Current Employee              Group Leader  Volkswagen Group
# 22473  Current Employee        Anonymous Employee  Volkswagen Group
# 22474  Current Employee  Customer Service Advisor  Volkswagen Group
#
#                   Sector       Date
# 0      Consumer Cyclical   2020-7-1
# 1      Consumer Cyclical   2020-7-1
# 2      Consumer Cyclical  2020-6-30
# 3      Consumer Cyclical  2020-6-29
# 4      Consumer Cyclical  2020-6-28
# ...                  ...        ...
# 22470  Consumer Cyclical  2018-7-12
# 22471  Consumer Cyclical   2018-7-8
# 22472  Consumer Cyclical  2018-6-27
# 22473  Consumer Cyclical  2018-6-25
# 22474  Consumer Cyclical  2018-6-12
#
# [22475 rows x 13 columns]

# %%
def string_to_date(date_str):
    try:
        return datetime.strptime(date_str, '%Y-%m-%d')
    except:
        return datetime.strptime('1800-1-1', '%Y-%m-%d')
    
def string_to_YM(date_str):
    try:
        return datetime.strptime(date_str, '%Y-%m')
    except:
        return datetime.strptime('1800-1-1', '%Y-%m-%d')

reviews_df['Date'] = reviews_df['Date'].apply(lambda x: string_to_date(x))

reviews_df['Year-Month'] = reviews_df.apply(lambda x: string_to_YM('-'.join([str(x['Year']), str(x['Month'])])), axis=1)

# %%
reviews_df
# Out:
#        Company_id                                       ReviewTitle  Rating  \
# 0               1                                         Part Time     4.0
# 1               1                               Terrible experience     1.0
# 2               1                                               Top     5.0
# 3               1                                   Sales Assistant     4.0
# 4               1  My experience is too maintain the task and group     2.0
# ...           ...                                               ...     ...
# 22470          50                           New Projects Specialist     5.0
# 22471          50                             good global practices     3.0
# 22472          50                                    company reviwe     3.0
# 22473          50                         Good Money, Tough Culture     3.0
# 22474          50                                   Service advisor     5.0
#
#                                                     Pros  \
# 0      Friendly colleagues, willing to give you disco...
# 1      Some nice welcoming colleagues and benefits (M...
# 2             Work-Life Balance, nice offices, top sport
# 3        Staff helpfulPay was goof Staff are respectuful
# 4         My biggest dream is to work with Adidas family
# ...                                                  ...
# 22470  Relationships, expertise, and logistics knowledge
# 22471    Unique global atndards and less local practices
# 22472                  good work culture and environment
# 22473  Volkswagen pays very well and the bonus is pre...
# 22474           Good communication with higher officials
#
#                                                     Cons  Year  Month  Day  \
# 0      There are some politics going on (like any oth...  2020      7    1
# 1      Really poor culture and collaboration spirit, ...  2020      7    1
# 2                   Global company, long decision making  2020      6   30
# 3                              Might get a little hectic  2020      6   29
# 4      Difficult to maintain but once know easy to ha...  2020      6   28
# ...                                                  ...   ...    ...  ...
# 22470  A lor of time to grow in the company, few prom...  2018      7   12
# 22471      salary low promotion strategy not encpuraging  2018      7    8
# 22472         unstable top management ,less transparency  2018      6   27
# 22473  The culture is very hierarchal and the managem...  2018      6   25
# 22474                         Not a clear follow of work  2018      6   12
#
#                JobTitle      EmployeeRelationship           Company  \
# 0       Former Employee        Anonymous Employee            Adidas
# 1       Former Employee         Software Engineer            Adidas
# 2      Current Employee                Manager/In            Adidas
# 3       Former Employee           Sales Assistant            Adidas
# 4       Former Employee         Questions Solving            Adidas
# ...                 ...                       ...               ...
# 22470  Current Employee        Anonymous Employee  Volkswagen Group
# 22471   Former Employee                   Manager  Volkswagen Group
# 22472  Current Employee              Group Leader  Volkswagen Group
# 22473  Current Employee        Anonymous Employee  Volkswagen Group
# 22474  Current Employee  Customer Service Advisor  Volkswagen Group
#
#                   Sector       Date Year-Month
# 0      Consumer Cyclical 2020-07-01 2020-07-01
# 1      Consumer Cyclical 2020-07-01 2020-07-01
# 2      Consumer Cyclical 2020-06-30 2020-06-01
# 3      Consumer Cyclical 2020-06-29 2020-06-01
# 4      Consumer Cyclical 2020-06-28 2020-06-01
# ...                  ...        ...        ...
# 22470  Consumer Cyclical 2018-07-12 2018-07-01
# 22471  Consumer Cyclical 2018-07-08 2018-07-01
# 22472  Consumer Cyclical 2018-06-27 2018-06-01
# 22473  Consumer Cyclical 2018-06-25 2018-06-01
# 22474  Consumer Cyclical 2018-06-12 2018-06-01
#
# [22475 rows x 14 columns]

# %% [markdown]
# ## 3. Company exploration

# %% [markdown]
# ### 3.1 Companies and reviews per sector

# %%
plt.figure(figsize=(8,5))

(companies
 .groupby('Sector')
 .count()
 .id
 .plot
 .bar()
)

plt.ylim(top = 10)

plt.tight_layout()

# %%
plt.figure(figsize=(8,5))

(reviews_df
 .groupby('Sector')
 .count()
 .Company_id
 .plot
 .bar()
)

plt.tight_layout()

# %% [markdown]
# ### 3.2 Companies per industry

# %%
plt.figure(figsize=(16,6))

(companies
 .groupby('Industry')
 .count()
 .id
 .plot
 .bar()
)

plt.ylim(top = 6)

plt.tight_layout()

# %% [markdown]
# ## 4. Review/ratings exploration

# %%
min_date = datetime.strptime('2018-7-1', '%Y-%m-%d')
max_date = datetime.strptime('2020-6-30', '%Y-%m-%d')

# %% [markdown]
# ### 4.1 Mean rating - per month & sector

# %%
reviews_MonthSector = pd.DataFrame(reviews_df[(reviews_df.Date >= min_date) & (reviews_df.Date <= max_date)]
 .groupby(['Sector', 'Year-Month'])
 .agg(['count', 'mean'])
)

reviews_MonthSector = pd.DataFrame(
    reviews_MonthSector.to_records()
)[['Sector', 'Year-Month', "('Rating', 'mean')", "('Rating', 'count')"]]

reviews_MonthSector.columns = ['Sector', 'Year-Month', 'Rating', 'Count']

# %%
# add sector to the DF
sectors = reviews_MonthSector.Sector.unique()

# add 3-month rating average to the DF
reviews_MonthSector['3M_Average']=0
i=0

for sector in sectors:
    avg = reviews_MonthSector[reviews_MonthSector.Sector==sector].Rating.rolling(window=3).mean()
    
    start = i
    end = i+avg.shape[0]
    reviews_MonthSector.iloc[start:end, -1] = avg
    
    i+=avg.shape[0]

# %%
reviews_MonthSector
# Out:
#               Sector Year-Month    Rating  Count  3M_Average
# 0    Basic Materials 2018-07-01  3.285714     14         NaN
# 1    Basic Materials 2018-08-01  3.533333     15         NaN
# 2    Basic Materials 2018-09-01  4.214286     14    3.677778
# 3    Basic Materials 2018-10-01  3.642857     14    3.796825
# 4    Basic Materials 2018-11-01  3.200000     10    3.685714
# ..               ...        ...       ...    ...         ...
# 256        Utilities 2020-02-01  3.235294     17    3.343583
# 257        Utilities 2020-03-01  3.789474     19    3.424923
# 258        Utilities 2020-04-01  3.466667     15    3.497145
# 259        Utilities 2020-05-01  3.500000      8    3.585380
# 260        Utilities 2020-06-01  3.615385     13    3.527350
#
# [261 rows x 5 columns]

# %%
fig, axes = plt.subplots(len(sectors),1, figsize = (16,5*len(sectors) ))

for i, sector in enumerate(sectors):
    no_companies = companies[companies.Sector == sector].shape[0]
    
    axes[i].set_xlabel('Date', fontsize=14)
    axes[i].set_title(f'{sector}: {no_companies} companies', fontsize=16)

    color = 'tab:blue'
    axes[i].set_ylabel('Count', color=color, fontsize=12)  # we already handled the x-label with ax1
    axes[i].bar(
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['Year-Month'],
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['Count'],
        color=color,
        width=8
    )
    axes[i].tick_params(axis='y', labelcolor=color)

    ax2 = axes[i].twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:green'

    ax2.set_ylabel('Rating (mean)', color=color, fontsize=12)
    ax2.plot(
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['Year-Month'],
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['Rating'],
        color=color,
        linewidth=3
    )
    ax2.plot(
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['Year-Month'],
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['3M_Average'],
        color='tab:purple',
        linewidth=3
    )
    ax2.tick_params(axis='y', labelcolor=color)

plt.tight_layout(pad=3.0)

# %% [markdown]
# ### 4.2 Change of mean rating - per month & sector

# %%
reviews_MonthSector['Difference'] = 0
i=0

for sector in sectors:
    diff = np.array(
        reviews_MonthSector[reviews_MonthSector.Sector == sector]['Rating'].diff()
    )
    start = i
    end = i+diff.shape[0]
    
    reviews_MonthSector.iloc[i:end, -1] = diff
    i += diff.shape[0]
    
plt.figure(figsize = (16,12))
sns.lineplot('Year-Month', 'Difference', data = reviews_MonthSector, hue = 'Sector')
plt.tight_layout()

# %%
reviews_MonthSector
# Out:
#               Sector Year-Month    Rating  Count  Difference  3M_Average
# 0    Basic Materials 2018-07-01  3.285714     14           0         NaN
# 1    Basic Materials 2018-08-01  3.533333     15           0    0.247619
# 2    Basic Materials 2018-09-01  4.214286     14           0    0.680952
# 3    Basic Materials 2018-10-01  3.642857     14           0   -0.571429
# 4    Basic Materials 2018-11-01  3.200000     10           0   -0.442857
# ..               ...        ...       ...    ...         ...         ...
# 256        Utilities 2020-02-01  3.235294     17           0   -0.014706
# 257        Utilities 2020-03-01  3.789474     19           0    0.554180
# 258        Utilities 2020-04-01  3.466667     15           0   -0.322807
# 259        Utilities 2020-05-01  3.500000      8           0    0.033333
# 260        Utilities 2020-06-01  3.615385     13           0    0.115385
#
# [261 rows x 6 columns]

# %% [markdown]
# ## 5. Reviews-Employees ratio
