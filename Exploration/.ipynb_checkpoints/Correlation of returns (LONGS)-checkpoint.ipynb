# %% [markdown]
# ## Settings

# %%
parameter = 'Reviews' # choose from Rewies or New (for rating)

# %%
from os import listdir
from os.path import isfile, join

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
main_path = f'C:\\Data\\UCL\\@MSc Project - Data and Sources\\Sentiment results\\Portfolios\\{parameter}'

# %% [markdown]
# ## Load the data

# %%
files = [f for f in listdir(main_path) if ( isfile(join(main_path, f)) ) and ('RETURNS_LONGS' in f) and ('Weighted' not in f)]

# %%
data = {f: pd.read_csv(join(main_path, f), index_col=0) for f in files}

# %%
data.keys()
# Out:
# dict_keys(['RETURNS_LONGS_S&P 500_low_risk.csv', 'RETURNS_LONGS_S&P 500_Momentum.csv', 'RETURNS_LONGS_S&P 500_Reviews_1M.csv', 'RETURNS_LONGS_S&P 500_Reviews_1M_Diff.csv', 'RETURNS_LONGS_S&P 500_Reviews_3M.csv', 'RETURNS_LONGS_S&P 500_Reviews_3M_Diff.csv'])

# %% [markdown]
# ## Get months return

# %%
min_dim = min([dataset.shape[1] for dataset in data.values()])

month_returns = {
    key: dataset.iloc[:,-min_dim:].mean(axis=0) for (key, dataset) in data.items()
}

month_returns_df = pd.DataFrame(month_returns)

# %% [markdown]
# ## Get correlation and corresponding heatmap

# %%
names=['Low_risk', 'Momentum', '1M', '$\Delta$1M', '3M', '$\Delta$3M']

corr_matrix = month_returns_df.corr()
corr_matrix.columns = names
corr_matrix.index = names

# %%
plt.figure(figsize=(8,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt='.2f',
    annot_kws={'size': 18},
    cbar=False,
    cmap='coolwarm',
    square=True,
    vmin=0.0
)


plt.tight_layout()
plt.savefig(f'C:\\Data\\UCL\\@MSc Project - Data and sources\\Images\\corr_{parameter}.png')
